# %% [markdown]
# - [Naive Bayes, (KNN), Decision Tree[6-8] Food Delivery Time Prediction](https://docs.google.com/document/d/1em8JyhIehJX-x1cjlSK0sONHaniyHM-mWhUwI-e2HUM/edit?usp=sharings)
# - [Naive Bayes, (KNN), Decision Tree[6-8] Global Pollution Analysis and Energy Recovery](https://docs.google.com/document/d/1ERpKoZzB4pTuk_hhYHMFfh2zEmgIOToAxQZPb7XJ780/edit?usp=sharing)
