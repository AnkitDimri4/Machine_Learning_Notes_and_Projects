# %% [markdown]
# - [Deforestation Issue Analysis Using Support Vector Machine (SVM) 15](https://docs.google.com/document/d/1Pvq6ySRo3hUofZSP14vK42V9_pAWuiE89gden6Gl_5k/edit?usp=sharing)
#
# - [Report](https://docs.google.com/document/d/1YIUbjtGUmKc3iz6p2djA5S_lG1YFMvStkysEiGdar-o/edit?usp=sharing)

# %%
import numpy as np
import pandas as pd

# Define the columns
columns = [
    "Country", "Year", "Forest_Loss_Area_km2", "Tree_Cover_Loss_percent", "CO2_Emission_mt", 
    "Rainfall_mm", "Population", "GDP_Billion_USD", "Agriculture_Land_Percent", 
    "Deforestation_Policy_Strictness", "Corruption_Index", "International_Aid_Million_USD", 
    "Illegal_Lumbering_Incidents", "Protected_Areas_Percent"
]

# Randomly generating 100 rows of data
new_data = {
    "Country": np.random.choice(["Brazil", "Indonesia", "Russia", "Australia", "India"], 100),
    "Year": np.random.choice(range(2000, 2025), 100),
    "Forest_Loss_Area_km2": np.random.randint(500, 5000, 100),
    "Tree_Cover_Loss_percent": np.random.uniform(1.5, 10.0, 100),
    "CO2_Emission_mt": np.random.randint(10, 500, 100),
    "Rainfall_mm": np.random.uniform(1000, 3000, 100),
    "Population": np.random.randint(1000000, 100000000, 100),
    "GDP_Billion_USD": np.random.uniform(50, 5000, 100),
    "Agriculture_Land_Percent": np.random.uniform(10, 60, 100),
    "Deforestation_Policy_Strictness": np.random.choice([1, 2, 3, 4], 100),  # 1: Very Weak, 2: Weak, 3: Moderate, 4: Strong
    "Corruption_Index": np.random.uniform(0, 100, 100),  # 0: Highly Corrupt, 100: No Corruption
    "International_Aid_Million_USD": np.random.randint(0, 500, 100),
    "Illegal_Lumbering_Incidents": np.random.randint(0, 200, 100),
    "Protected_Areas_Percent": np.random.uniform(5, 30, 100),
}

# Creating the DataFrame
new_df = pd.DataFrame(new_data)

# Saving the extended dataset to a new CSV file
extended_file_path = '/mnt/data/deforestation_dataset_extended_v2.csv'
new_df.to_csv(extended_file_path, index=False)

extended_file_path

# %%
import numpy as np
import pandas as pd

# Define the columns
columns = [
    "Country", "Year", "Forest_Loss_Area_km2", "Tree_Cover_Loss_percent", "CO2_Emission_mt", 
    "Rainfall_mm", "Population", "GDP_Billion_USD", "Agriculture_Land_Percent", 
    "Deforestation_Policy_Strictness", "Corruption_Index", "International_Aid_Million_USD", 
    "Illegal_Lumbering_Incidents", "Protected_Areas_Percent"
]

# Randomly generating 100 rows of data
new_data = {
    "Country": np.random.choice(["Brazil", "Indonesia", "Russia", "Australia", "India"], 100),
    "Year": np.random.choice(range(2000, 2025), 100),
    "Forest_Loss_Area_km2": np.random.randint(500, 5000, 100),
    "Tree_Cover_Loss_percent": np.random.uniform(1.5, 10.0, 100),
    "CO2_Emission_mt": np.random.randint(10, 500, 100),
    "Rainfall_mm": np.random.uniform(1000, 3000, 100),
    "Population": np.random.randint(1000000, 100000000, 100),
    "GDP_Billion_USD": np.random.uniform(50, 5000, 100),
    "Agriculture_Land_Percent": np.random.uniform(10, 60, 100),
    "Deforestation_Policy_Strictness": np.random.choice([1, 2, 3, 4], 100),  # 1: Very Weak, 2: Weak, 3: Moderate, 4: Strong
    "Corruption_Index": np.random.uniform(0, 100, 100),  # 0: Highly Corrupt, 100: No Corruption
    "International_Aid_Million_USD": np.random.randint(0, 500, 100),
    "Illegal_Lumbering_Incidents": np.random.randint(0, 200, 100),
    "Protected_Areas_Percent": np.random.uniform(5, 30, 100),
}

# Creating the DataFrame
new_df = pd.DataFrame(new_data)

# Saving the extended dataset to a new CSV file
extended_file_path = './deforestation_dataset_extended_v2.csv'
new_df.to_csv(extended_file_path, index=False)

extended_file_path
# Out:
# './deforestation_dataset_extended_v2.csv'

# %%
import pandas as pd
import numpy as np

# Define the columns
columns = [
    "Country", "Year", "Forest_Loss_Area_km2", "Tree_Cover_Loss_percent", "CO2_Emission_mt", 
    "Rainfall_mm", "Population", "GDP_Billion_USD", "Agriculture_Land_Percent", 
    "Deforestation_Policy_Strictness", "Corruption_Index", "International_Aid_Million_USD", 
    "Illegal_Lumbering_Incidents", "Protected_Areas_Percent"
]

# Generate the dataset with different years for each country
countries = ["Brazil", "Indonesia", "Russia", "Australia", "India"]
years = np.random.choice(range(1925, 2025), 100)

# Randomly generate data for each country and year combination
new_data = {
    "Country": np.random.choice(countries, 100),
    "Year": years,
    "Forest_Loss_Area_km2": np.random.randint(500, 5000, 100),
    "Tree_Cover_Loss_percent": np.random.uniform(1.5, 10.0, 100),
    "CO2_Emission_mt": np.random.randint(10, 500, 100),
    "Rainfall_mm": np.random.uniform(1000, 3000, 100),
    "Population": np.random.randint(1000000, 100000000, 100),
    "GDP_Billion_USD": np.random.uniform(50, 5000, 100),
    "Agriculture_Land_Percent": np.random.uniform(10, 60, 100),
    "Deforestation_Policy_Strictness": np.random.choice([1, 2, 3, 4], 100),  # 1: Very Weak, 2: Weak, 3: Moderate, 4: Strong
    "Corruption_Index": np.random.uniform(0, 100, 100),  # 0: Highly Corrupt, 100: No Corruption
    "International_Aid_Million_USD": np.random.randint(0, 500, 100),
    "Illegal_Lumbering_Incidents": np.random.randint(0, 200, 100),
    "Protected_Areas_Percent": np.random.uniform(5, 30, 100),
}

# Create the DataFrame
new_df = pd.DataFrame(new_data)

# Save the dataset to a new CSV file
extended_file_path = './deforestation_dataset_with_diff_years.csv'
new_df.to_csv(extended_file_path, index=False)

extended_file_path
# Out:
# './deforestation_dataset_with_diff_years.csv'

# %% [markdown]
# **Assignment: Deforestation Issue Analysis Using Support Vector Machine (SVM)**
#
# **Dataset:**
# The dataset provided for this assignment is titled **deforestation_dataset.csv**. It contains data related to deforestation across multiple countries for different years. The key variables in the dataset include tree cover loss, CO2 emissions, rainfall, population, GDP, and several other factors contributing to deforestation.
#
# ---
#
# ### **Phase 1: Data Preprocessing**
#
# 1. **Loading the Data:**
#    - Load the dataset **deforestation_dataset.csv** into your programming environment.
#    - Inspect the dataset for any missing values, inconsistent data, or any other anomalies.
#
# 2. **Data Cleaning:**
#    - Handle missing values (e.g., impute, remove, or replace them as necessary).
#    - Convert categorical columns (such as `Deforestation_Policy_Strictness`, `Corruption_Index`) into numerical values using encoding methods (e.g., label encoding or one-hot encoding).
#
# 3. **Feature Scaling:**
#    - Normalize or standardize numerical features such as `CO2_Emission_mt`, `Population`, `GDP_Billion_USD`, etc., to ensure the SVM model works effectively.
#    - Determine the importance of each feature in the model and decide if any feature selection is needed.
#
# 4. **Split Data into Training and Testing Sets:**
#    - Split the dataset into training (80%) and testing (20%) sets.
#    - Use the `train_test_split` function from a relevant library to ensure the data is shuffled and the split is random.
#
# ---
#
# ### **Phase 2: Model Building and Evaluation**
#
# 1. **Train the Support Vector Machine (SVM) Model:**
#    - Train an SVM model to predict deforestation levels. The target variable can be either `Forest_Loss_Area_km2` or `Tree_Cover_Loss_percent`, depending on your analysis.
#    - Implement a linear kernel for the initial model, and evaluate its performance on the training data.
#
# 2. **Model Evaluation:**
#    - Use evaluation metrics such as **accuracy**, **precision**, **recall**, and **F1-score** to assess the model’s performance.
#    - Visualize the SVM decision boundaries (if applicable) or evaluate feature importance using the trained model.
#
# 3. **Hyperparameter Tuning:**
#    - Experiment with different SVM kernels (e.g., polynomial, RBF) to improve model performance.
#    - Tune hyperparameters such as `C`, `gamma`, and kernel types using grid search or random search methods.
#    - Apply cross-validation techniques to validate the model’s robustness.
#
# ---
#
# ### **Phase 3: Feature Analysis and Interpretation**
#
# 1. **Analyze Feature Importance:**
#    - Investigate which features have the most significant impact on deforestation based on the model's output.
#    - Generate a report on how each feature (e.g., `Rainfall_mm`, `GDP_Billion_USD`, `Population`) influences deforestation levels.
#
# 2. **Interpretation of Results:**
#    - Provide insights based on the SVM model about the key contributors to deforestation.
#    - Discuss how factors like **GDP**, **policy strictness**, and **illegal lumbering incidents** influence deforestation in the countries studied.
#
# ---
#
# ### **Phase 4: Reporting and Recommendations**
#
# 1. **Visualize the Results:**
#    - Create visualizations (graphs, charts) that illustrate key relationships between the features and deforestation levels.
#    - Include scatter plots, bar charts, or heatmaps to better understand the feature impact.
#
# 2. **Write a Comprehensive Report:**
#    - Provide a detailed analysis of the findings from your model, including:
#      - How deforestation is influenced by variables like population, economic factors, and policy strictness.
#      - Possible regions or countries where deforestation can be mitigated using specific interventions.
#
# 3. **Recommendations for Deforestation Mitigation:**
#    - Based on your findings, make recommendations on policies or actions that could help reduce deforestation, considering economic, social, and environmental aspects.
#
# 4. **Presentation:**
#    - Prepare a presentation summarizing your findings, methodology, and results.
#    - Include key insights and actionable recommendations for decision-makers.
#
# ---
#
# ### **Deliverables:**
#
# 1. **Code Implementation:**
#    - A Jupyter notebook or Python script that includes the entire SVM model development process, from data preprocessing to final model evaluation.
#
# 2. **Report:**
#    - A 2-3 page report summarizing your analysis, model evaluation, and insights on deforestation trends.
#    - Include visualizations and charts to back up your analysis.
#
# 3. **Presentation:**
#    - A PowerPoint or similar presentation that summarizes the key findings from your assignment.
#
# ---
#
# ### **Evaluation Criteria:**
#
# - **Data Preprocessing and Cleaning:** Proper handling of missing values and normalization of data.
# - **Model Accuracy and Performance:** SVM model's ability to predict deforestation effectively.
# - **Feature Engineering and Importance:** Clear explanation of the most influential factors on deforestation.
# - **Quality of Analysis and Interpretation:** Depth of insights provided based on model outputs.
# - **Visualizations and Reporting:** Clear, insightful, and well-organized report and presentation.
#
# ---
#
# **Note:** The dataset used in this assignment is **deforestation_dataset.csv**, which contains data related to deforestation in various countries and years. Make sure to use the correct target variable and model evaluation techniques to derive actionable insights on the deforestation issue.
